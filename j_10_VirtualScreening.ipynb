# %% [markdown]
# # 가상 스크리닝
#
#
# - 어떤 조건을 만족하는 분자를 찾아내는 작업을 화학 실험을 수행하지 않고 머신러닝 모델로 찾는 것을 말한다
# - 여기서는 예제로 ERK2 단백질을 억제하는 분자를 선별하는 모델을 만든다
#  - Extracellular signal-regulated kinase (다수의 생화학적 신호에 관여하고 세포의 증식 분화 전사조절에 관여)
#  - 비소세포성 폐암 non-small cell lung cancer과 흑색종(피부암)에 대해 임상시험중
#
# - 그래프 컨볼류션 모델을 사용한다

# %% [markdown]
# # import

# %%
# !pip install DeepChem
# !pip install tensorflow==2.9
# Out:
# Requirement already satisfied: DeepChem in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from DeepChem) (1.4.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from DeepChem) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from DeepChem) (2.1.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from DeepChem) (1.5.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from DeepChem) (1.13.3)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from DeepChem) (1.13.1)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/dist-packages (from DeepChem) (2024.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->DeepChem) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->DeepChem) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->DeepChem) (2024.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit->DeepChem) (10.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->DeepChem) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->DeepChem) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->DeepChem) (1.16.0)
# Requirement already satisfied: tensorflow==2.9 in /usr/local/lib/python3.10/dist-packages (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.64.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (3.11.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (24.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.16.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (0.37.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.9) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.2.2)

# %%
import deepchem as dc
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
from rdkit.Chem import Descriptors
from rdkit.Chem import rdmolops
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import rdMolDescriptors as rdmd
from deepchem.models import GraphConvModel
# Out:
# WARNING:deepchem.feat.molecule_featurizers.rdkit_descriptors:No normalization for SPS. Feature removed!
# WARNING:deepchem.feat.molecule_featurizers.rdkit_descriptors:No normalization for AvgIpc. Feature removed!
# WARNING:deepchem.models.torch_models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# WARNING:deepchem.models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.10/dist-packages/deepchem/models/torch_models/__init__.py)
# WARNING:deepchem.models:Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# WARNING:deepchem.models:Skipped loading some Jax models, missing a dependency. No module named 'haiku'

# %%
import numpy as np
import pandas as pd
import sys
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 데이터
#
# - DUD-E 데이터베이스에서 활성 및 비활성 분자 데이터를 다운받아 사용한다
# - 분자 데이터는 SMILES 로 표현되어 있으며 이를 데이터프레임에 불러온다
# - AddMoleculeColumnToFrame()를 사용해 SMILES에 해당하는 Mol 객체를 데이터프레임에 추가할 수 있다

# %%
active_df = pd.read_csv("https://raw.githubusercontent.com/deepchem/DeepLearningLifeSciences/master/Chapter11/mk01/actives_final.ism",
                        header=None,sep=" ")
print(active_df.shape)
active_df[:3]
# Out:
# (79, 3)
#                                                    0       1             2
# 0  Cn1ccnc1Sc2ccc(cc2Cl)Nc3c4cc(c(cc4ncc3C#N)OCCC...  168691  CHEMBL318804
# 1  C[C@@]12[C@@H]([C@@H](CC(O1)n3c4ccccc4c5c3c6n2...   86358     CHEMBL162
# 2  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575087  CHEMBL576683

# %%
active_rows, active_cols = active_df.shape
active_df.columns = ["SMILES","ID","ChEMBL_ID"]
active_df["label"] = ["Active"]*active_rows
PandasTools.AddMoleculeColumnToFrame(active_df,"SMILES","Mol")

# %%
active_df[:3]
# Out:
#                                               SMILES      ID     ChEMBL_ID  \
# 0  Cn1ccnc1Sc2ccc(cc2Cl)Nc3c4cc(c(cc4ncc3C#N)OCCC...  168691  CHEMBL318804
# 1  C[C@@]12[C@@H]([C@@H](CC(O1)n3c4ccccc4c5c3c6n2...   86358     CHEMBL162
# 2  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575087  CHEMBL576683
#
#     label                                               Mol
# 0  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f4970>
# 1  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f49e0>
# 2  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f4a50>

# %% [markdown]
# ## 특성값 추가
# - 분자량 molecular weight
# - 분배 계수 partition coefficeint(LogP)
# - 전하 charge (양인지 음인지)

# %%
def add_property_columns_to_df(df_in):
    df_in["mw"] = [Descriptors.MolWt(mol) for mol in df_in.Mol]
    df_in["logP"] = [Descriptors.MolLogP(mol) for mol in df_in.Mol]
    df_in["charge"] = [rdmolops.GetFormalCharge(mol) for mol in df_in.Mol]

# %%
add_property_columns_to_df(active_df)
active_df.head()
# Out:
#                                               SMILES      ID     ChEMBL_ID  \
# 0  Cn1ccnc1Sc2ccc(cc2Cl)Nc3c4cc(c(cc4ncc3C#N)OCCC...  168691  CHEMBL318804
# 1  C[C@@]12[C@@H]([C@@H](CC(O1)n3c4ccccc4c5c3c6n2...   86358     CHEMBL162
# 2  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575087  CHEMBL576683
# 3  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575065  CHEMBL571484
# 4  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575047  CHEMBL568937
#
#     label                                               Mol       mw     logP  \
# 0  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f4970>  565.099  5.49788
# 1  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f49e0>  466.541  4.35400
# 2  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f4a50>  527.915  4.96202
# 3  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f4ac0>  491.935  4.36922
# 4  Active  <rdkit.Chem.rdchem.Mol object at 0x7f13297f4b30>  487.991  5.12922
#
#    charge
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## 비활성화 데이터

# %%
decoy_df = pd.read_csv("https://raw.githubusercontent.com/deepchem/DeepLearningLifeSciences/master/Chapter11/mk01/decoys_final.ism",
                       header=None,sep=" ")
decoy_df.columns = ["SMILES","ID"]
decoy_rows, decoy_cols = decoy_df.shape
decoy_df["label"] = ["Decoy"]*decoy_rows
PandasTools.AddMoleculeColumnToFrame(decoy_df,"SMILES","Mol")
add_property_columns_to_df(decoy_df)

# %% [markdown]
# - 활성 및 비확성 데이터를 합친다

# %%
tmp_df = pd.concat([active_df, decoy_df])
tmp_df.shape
# Out:
# (4629, 8)

# %% [markdown]
# ## 데이터 탐색
#
# - violin plot

# %%
sns.violinplot(x=tmp_df["label"],y=tmp_df["mw"]);

# %% [markdown]
# - 위 그래프를 보면 분자량 분포는 비슷하다
# - 400mw 이하의 분자들이 비활성 분자 데이터셋에 좀 더 많이 들어 있다

# %%
sns.violinplot(x=tmp_df["label"],y=tmp_df["logP"]);

# %%
sns.violinplot(x=tmp_df["label"],y=tmp_df["charge"]);

# %% [markdown]
# - 활성 분자는 모두 중성이다
# - 비활성 분자는 일부 +1과 -1이 있다

# %%
charged = decoy_df[decoy_df["charge"] != 0]
charged.shape[0]/decoy_df.shape[0]
# Out:
# 0.16175824175824177

# %% [markdown]
# - 비활성 분자의 16%가 전하를 띠고 있다
# - 전하 차이에 의해 머신러닝 모델이 바이어스가 생기게 되므로, 비활성 분자의 화학 구조를 수정하여 전하를 제거하겠다
# - 아래는 이를 위한 함수 정의이다

# %%
def _InitialiseNeutralisationReactions():
    patts= (
        # Imidazoles
        ('[n+;H]','n'),
        # Amines
        ('[N+;!H0]','N'),
        # Carboxylic acids and alcohols
        ('[$([O-]);!$([O-][#7])]','O'),
        # Thiols
        ('[S-;X1]','S'),
        # Sulfonamides
        ('[$([N-;X2]S(=O)=O)]','N'),
        # Enamines
        ('[$([N-;X2][C,N]=C)]','N'),
        # Tetrazoles
        ('[n-]','[nH]'),
        # Sulfoxides
        ('[$([S-]=O)]','S'),
        # Amides
        ('[$([N-]C=O)]','N'),
        )
    return [(Chem.MolFromSmarts(x),Chem.MolFromSmiles(y,False)) for x,y in patts]

_reactions=None

def NeutraliseCharges(smiles, reactions=None):
    global _reactions
    if reactions is None:
        if _reactions is None:
            _reactions=_InitialiseNeutralisationReactions()
        reactions=_reactions
    mol = Chem.MolFromSmiles(smiles)
    replaced = False
    for i,(reactant, product) in enumerate(reactions):
        while mol.HasSubstructMatch(reactant):
            replaced = True
            rms = AllChem.ReplaceSubstructs(mol, reactant, product)
            mol = rms[0]
    if replaced:
        return (Chem.MolToSmiles(mol,True), True)
    else:
        return (smiles, False)

# %%
revised_decoy_df = decoy_df[["SMILES","ID","label"]].copy()
revised_decoy_df["SMILES"] = [NeutraliseCharges(x)[0] for x in revised_decoy_df["SMILES"]]
print(revised_decoy_df.shape)
revised_decoy_df[:3]
# Out:
# (4550, 3)
#                                               SMILES         ID  label
# 0                         C1COCCNC(=S)NCCOCCNC(=S)N1  C03897368  Decoy
# 1            c1cc(ccc1[C@H]2c3ccc(cc3OC(=C2C#N)N)N)O  C00242247  Decoy
# 2  C[C@]12CC[C@H](C[C@@H]1CC[C@@H]3[C@@H]2C(=O)C[...  C04096778  Decoy

# %% [markdown]
# - 중성화된 SMILES는 첫 번째 컬럼에 들어 있다

# %% [markdown]
# - 특성을 다시 계산한다
# - 전하를 띤 샘플의 수가 감소했다

# %%
PandasTools.AddMoleculeColumnToFrame(revised_decoy_df,"SMILES","Mol")
add_property_columns_to_df(revised_decoy_df)
new_tmp_df = pd.concat([active_df, revised_decoy_df])
sns.violinplot(x=new_tmp_df["label"],y=new_tmp_df["charge"])
# Out:
# <Axes: xlabel='label', ylabel='charge'>

# %%
charged = revised_decoy_df[revised_decoy_df["charge"] != 0]
charged.shape[0]/revised_decoy_df.shape[0]
# Out:
# 0.0026373626373626374

# %% [markdown]
# - 활성을 1로 비활성을 0으로 인코딩한다

# %%
active_df["is_active"] = [1] * active_df.shape[0]
revised_decoy_df["is_active"] = [0] * revised_decoy_df.shape[0]
combined_df = pd.concat([active_df, revised_decoy_df])[["SMILES","ID","is_active"]]
combined_df.head()
# Out:
#                                               SMILES      ID  is_active
# 0  Cn1ccnc1Sc2ccc(cc2Cl)Nc3c4cc(c(cc4ncc3C#N)OCCC...  168691          1
# 1  C[C@@]12[C@@H]([C@@H](CC(O1)n3c4ccccc4c5c3c6n2...   86358          1
# 2  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575087          1
# 3  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575065          1
# 4  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...  575047          1

# %%
# 전처리한 데이터를 파일로 저장해둔다
combined_df.to_csv("dude_erk1_mk01.csv")

# %% [markdown]
# # 분류 모델
#
# - GCN 모델을 사용한다

# %% [markdown]
# ##  그래프 컨볼류션 모델 생성

# %%
def generate_graph_conv_model():
    batch_size = 128
    model = GraphConvModel(1, batch_size=batch_size,
             mode='classification', model_dir="./model_dir")
    return model

# %%
dataset_file = "dude_erk1_mk01.csv"
tasks = ["is_active"]
featurizer = dc.feat.ConvMolFeaturizer()
loader = dc.data.CSVLoader(tasks=tasks, feature_field="SMILES", featurizer=featurizer)
dataset = loader.create_dataset(dataset_file, shard_size=8192)
dataset
# Out:
# <DiskDataset X.shape: (4629,), y.shape: (4629, 1), w.shape: (4629, 1), task_names: ['is_active']>

# %% [markdown]
# - RandomSplitter() 사용 - 데이터를 래덤하게 나눈다
# - 화학 구조를 기반으로 데이터셋을 나누는 ScaffoleSplit(), 데이터를 군집화 한 후에 데이터셋을 나누는 ButinaSplitter()도 있다
# - 불균형 데이터에 대한 성능 평가시에는 매튜 상관계수 Matthews Correlarions Coefficients(MCC)를 사용한다
#  - +1이면 완벽한 예측, 0이면 랜덤 예측, -1이면 완전히 반대되는 예측을 의미한다
# - 모델을 5회 만들어 평균을 구한다 (랜덤 교차검증)

# %%
splitter = dc.splits.RandomSplitter()
metrics = [dc.metrics.Metric(dc.metrics.matthews_corrcoef, np.mean)]

training_score_list = []
validation_score_list = []
transformers = []
cv_folds = 5
for i in tqdm(range(0,cv_folds)):
    model = generate_graph_conv_model()
    train_dataset, valid_dataset, test_dataset = splitter.train_valid_test_split(dataset)
    model.fit(train_dataset)
    train_scores = model.evaluate(train_dataset, metrics, transformers)
    training_score_list.append(train_scores["mean-matthews_corrcoef"])
    validation_scores = model.evaluate(valid_dataset, metrics, transformers)
    validation_score_list.append(validation_scores["mean-matthews_corrcoef"])
print(training_score_list)
print(validation_score_list)
print(np.array(training_score_list).mean())
print(np.array(validation_score_list).mean())
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# [0.5823908519865434, 0.7275225405977639, 0.8289791101351985, 0.8143774003802622, 0.8108074851854256]
# [0.7047972264664374, 0.5760992378838319, 0.8433069208152789, 0.6741431187975722, 0.910853532390761]
# 0.7528154776570387
# 0.7418400072707761

# %%
np.array(training_score_list).mean(), np.array(validation_score_list).mean()
# Out:
# (0.7528154776570387, 0.7418400072707761)

# %%
sns.boxplot(x=["training"]*cv_folds+["validation"]*cv_folds,y=training_score_list+validation_score_list);

# %% [markdown]
# ## 검증 데이터 분류 예측

# %%
pred = [x.flatten() for x in model.predict(valid_dataset)]
pred_df = pd.DataFrame(pred,columns=["neg","pos"])
pred_df["active"] = [int(x) for x in valid_dataset.y]
pred_df["SMILES"] = valid_dataset.ids
pred_df.head()
# Out:
#         neg       pos  active  \
# 0  0.999800  0.000200       0
# 1  0.999981  0.000019       0
# 2  0.999964  0.000036       0
# 3  0.999617  0.000383       0
# 4  0.999937  0.000062       0
#
#                                               SMILES
# 0            COc1ccccc1c2nc(cs2)CN3C(=O)c4ccccc4C3=O
# 1  CCOc1cc(ccc1O)/C=N/NC(=O)CCCSc2nnc(n2N)c3ccccc3Br
# 2  C[C@@H]1CCCC[C@H]1NC(=O)NC(=O)CSc2nnc(n2N)c3cc...
# 3  C[C@H]1CCc2c(sc(c2C(=O)N)NC(=O)/C(=C/c3ccccc3O...
# 4  CC1=C([C@H](NC(=S)N1)c2cccc(c2)OC)C(=O)Nc3ccc(...

# %%
pred_df.sort_values("pos",ascending=False).head(5)
# Out:
#           neg       pos  active  \
# 284  0.040565  0.959435       1
# 103  0.044354  0.955646       1
# 338  0.063739  0.936261       1
# 245  0.093508  0.906492       1
# 332  0.122533  0.877467       1
#
#                                                 SMILES
# 284  c1ccc(cc1)CNC(=O)c2cc(c[nH]2)c3c(cn[nH]3)c4ccc...
# 103  c1cc(cc(c1)Cl)c2cn[nH]c2c3cc([nH]c3)C(=O)NC(CO...
# 338  CN(Cc1ccccc1)C(=O)c2cc(c[nH]2)c3c(cn[nH]3)c4cc...
# 245    CCN(C)C(=O)c1cc(c[nH]1)c2c(cn[nH]2)c3cccc(c3)Cl
# 332  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3cccc(c3...

# %%
sns.boxplot(x=pred_df.active,y=pred_df.pos)
# Out:
# <Axes: xlabel='active', ylabel='pos'>

# %% [markdown]
# - 위 그래프를 보면 활성 분자와 비활성 분자를 잘 구분하고 있는 것을 알 수 있다
# - False Negative 샘플 찾기

# %%
false_negative_df = pred_df.query("active == 1 & pos < 0.5").copy()

# %%
PandasTools.AddMoleculeColumnToFrame(false_negative_df,"SMILES","Mol")
false_negative_df
# Out:
#          neg       pos  active  \
# 25  0.955301  0.044699       1
# 75  0.990529  0.009471       1
#
#                                                SMILES  \
# 25  Cn1cc(c2c1nccc2c3ccc(cc3)C(=O)NCCO)/C=C\4/C(=O...
# 75  c1ccc2c(c1)c(c[nH]2)c3c(cnc(n3)N)c4ccc(cc4)C(F...
#
#                                                  Mol
# 25  <rdkit.Chem.rdchem.Mol object at 0x7f131c6e45f0>
# 75  <rdkit.Chem.rdchem.Mol object at 0x7f131c6e4740>

# %% [markdown]
# - False Positive 샘플 찾기

# %% [markdown]
# ## 모든 데이터로 학습
# - 모델의 성능을 향상시키기 위해서 검증데이터를 훈련에 사용

# %%
model.fit(dataset)
# Out:
# 0.0003516003489494324

# %% [markdown]
# - 앞에서 ERK2 단백질의 활성을 억제하는 분자를 예측하는 모델을 만들었다. 여기에 새로운 데이터셋을 사용하여 분자의 활성을 예측해보겠다
#  - COCONUT 데이터셋을 사용하겠다

# %% [markdown]
# ## rd_filters 적용
#
# - Pat Walters가 만든 스크립트로 잠재적으로 문제가 있는 분자를 걸러낸다
# - 생물학적 분석이 어려운 분자들을 제거하기 위해서 rd_filters.py를 사용
# - [rd_filters github](https://github.com/PatWalters/rd_filters)

# %%
model_backup = model

# %%
# 현재 폴더에 해당 git 설치
# !pip install git+https://github.com/PatWalters/rd_filters.git
# Out:
# Collecting git+https://github.com/PatWalters/rd_filters.git
#   Cloning https://github.com/PatWalters/rd_filters.git to /tmp/pip-req-build-sgqdpiak
#   Running command git clone --filter=blob:none --quiet https://github.com/PatWalters/rd_filters.git /tmp/pip-req-build-sgqdpiak
#   Resolved https://github.com/PatWalters/rd_filters.git to commit 3630f1a59150b4a203c2f06d8376a66d1d4c3f70
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rd_filters==0.1) (2.1.4)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from rd_filters==0.1) (0.6.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->rd_filters==0.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->rd_filters==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rd_filters==0.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rd_filters==0.1) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->rd_filters==0.1) (1.16.0)

# %%
# 사용법 안내
# !rd_filters -h
# Out:
# Usage:
# rd_filters filter --in INPUT_FILE --prefix PREFIX [--rules RULES_FILE_NAME] [--alerts ALERT_FILE_NAME][--np NUM_CORES]
# rd_filters template --out TEMPLATE_FILE [--rules RULES_FILE_NAME]
#
# Options:
# --in INPUT_FILE input file name
# --prefix PREFIX prefix for output file names
# --rules RULES_FILE_NAME name of the rules JSON file
# --alerts ALERTS_FILE_NAME name of the structural alerts file
# --np NUM_CORES the number of cpu cores to use (default is all)
# --out TEMPLATE_FILE parameter template file name

# %%
# coconut database 다운로드 후 파일 압축 해제 및 파일명 확인
! wget https://coconut.s3.uni-jena.de/prod/downloads/2024-09/coconut-09-2024.csv.zip
# !unzip ./coconut-09-2024.csv.zip
# Out:
# --2024-09-29 14:53:15--  https://coconut.s3.uni-jena.de/prod/downloads/2024-09/coconut-09-2024.csv.zip
# Resolving coconut.s3.uni-jena.de (coconut.s3.uni-jena.de)... 141.35.104.26, 141.35.104.25, 2001:638:1558:2368::8d23:6819, ...
# Connecting to coconut.s3.uni-jena.de (coconut.s3.uni-jena.de)|141.35.104.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88935618 (85M) [application/zip]
# Saving to: ‘coconut-09-2024.csv.zip.1’
#
# coconut-09-2024.csv 100%[===================>]  84.82M  22.8MB/s    in 4.1s
#
# 2024-09-29 14:53:19 (20.8 MB/s) - ‘coconut-09-2024.csv.zip.1’ saved [88935618/88935618]
#
# Archive:  ./coconut-09-2024.csv.zip
# replace coconut-09-2024.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: r
# new name:

# %%
coconut = pd.read_csv('./coconut-09-2024.csv')
coconut
# Out:
#                                            standard_inchi  \
# 0       InChI=1S/C43H53N9O14S2.Na/c1-5-22(3)35-36(57)4...
# 1       InChI=1S/C21H32O12/c1-9-14(23)16(25)18(27)21(3...
# 2       InChI=1S/C36H61N5O7/c1-21(2)18-27-35(47)48-28(...
# 3       InChI=1S/C22H22O9/c1-28-12-4-2-11(3-5-12)15-9-...
# 4       InChI=1S/C32H41N5O4/c1-6-18(4)28-32(41)36-12-8...
# ...                                                   ...
# 695128  InChI=1S/C19H19N3O4/c1-26-13-8-6-12(7-9-13)20-...
# 695129  InChI=1S/C30H30N2O10/c1-12-23(34)27(38)28(39)3...
# 695130  InChI=1S/C21H22O7/c1-11(2)4-5-13-15(23)7-6-14(...
# 695131  InChI=1S/C20H30O7/c1-17(2)4-3-12(23)18-8-27-20...
# 695132  InChI=1S/C45H38O18/c46-18-2-4-20-30(12-18)61-4...
#
#                  standard_inchi_key  \
# 0       DRKUXFLLRIKRHH-QDVYGYDXSA-M
# 1       OXHVQSRYUNGYOK-NUASCYGXSA-N
# 2       NEGZFRNAAJQQEG-NOFCQABOSA-N
# 3       DQIVYFNWBDHNFD-WHCFWRGISA-N
# 4       HKVSEIVDIONNKB-QWNGKRCASA-N
# ...                             ...
# 695128  HHSNDFVMRMIDBG-INIZCTEOSA-N
# 695129  VVPODVCQSZKNKL-RLOKSPFPSA-N
# 695130  LMFCHRAKSGPODM-OAQYLSRUSA-N
# 695131  IJWNAKYUVUUYTE-HMBONYETSA-N
# 695132  QZNRDKYJASOYMZ-JNGZPCCCSA-N
#
#                                          canonical_smiles    identifier
# 0       CC[C@@H]1NC(=O)[C@@H](NC(=O)[C@H](C)NC(=O)CNC(...  CNP0437004.1
# 1       COC1=CC=C(CCO[C@@H]2O[C@H](CO[C@@H]3O[C@@H](C)...  CNP0243002.1
# 2       C/C1=C\[C@@H](C(C)(C)C)OC(=O)[C@H](CC(C)C)N(C)...  CNP0458114.1
# 3       COC1=CC=C(C2=CC(=O)OC3=CC(O[C@@H]4O[C@H](CO)[C...  CNP0252086.2
# 4       CC[C@H](C)[C@H]1C(=O)N2CCC[C@H]2C(=O)N1C(=O)[C...  CNP0107934.1
# ...                                                   ...           ...
# 695128  COC1=CC=C(NC(=O)CC[C@@H]2NC(=O)C3=CC=CC=C3NC2=...  CNP0395779.1
# 695129  CC(=O)OC1=CC=C2C(=O)C3=C(O)C(CC4=CC=CC(C(N)N)=...  CNP0097600.1
# 695130  COC1=C([C@]2(O)COC3=CC(O)=CC(O)=C3C2=O)C=CC(O)...  CNP0212403.1
# 695131  CC1(C)CC[C@H](O)[C@]23COC(O)([C@@H](O)[C@H]12)...  CNP0494455.1
# 695132  OC1=CC=C2C(=C1)O[C@H](C1=CC(O)=C(O)C(O)=C1)[C@...  CNP0300293.2
#
# [695133 rows x 4 columns]

# %% [markdown]
# - 필터 수행
#  - 필터 수행 결과 29.5%가 통과하였다
#  - 생물학적 분석이 어려운 화합물을 제거
#  - 필터 결과는 coconut.csv에 저장된다. 필터를 통과한 SMILES 정보는 coconut.smi에 저장된다

# %%
with open('COCONUT_DB_absoluteSMILES.smi', 'w') as f:
        for id, smile in zip(coconut['identifier'], coconut['canonical_smiles']):
            f.write(smile + ' ' + id + '\n')

# %%
# !rd_filters filter --in ./COCONUT_DB_absoluteSMILES.smi --prefix coconut
# Out:
# using 2 cores
# Using alerts from Inpharmatica
# [14:54:15] WARNING: not removing hydrogen atom without neighbors
# [15:02:10] Unusual charge on atom 37 number of radical electrons set to zero
# [15:14:40] WARNING: not removing hydrogen atom without neighbors
# [15:15:18] WARNING: not removing hydrogen atom without neighbors
# [15:15:18] WARNING: not removing hydrogen atom without neighbors
# [15:16:54] WARNING: not removing hydrogen atom without neighbors
# Wrote SMILES for molecules passing filters to coconut.smi
# Wrote detailed data to coconut.csv
# 197794 of 695133 passed filters 28.5%
# Elapsed time 1438.51 seconds

# %% [markdown]
# ## 필터 결과
#
# - coconut.csv의 내용
#  - SMILES 문자열,
#  - 분자의 이름(NAME),
#  - 필터를 통과하지 못한 이유(FILTER),
#  - 분자량(MW, 500보다 크면 통과하지 못한다),
#  - 옥탄올/물 분배계수(LogP, 5보다 크면 통과하지 못한다)
#  - 수소결합의 공여체수 (HBD)

# %%
df = pd.read_csv("./coconut.csv")
df.head()
# Out:
#                                               SMILES          NAME  \
# 0  CC[C@@H]1NC(=O)[C@@H](NC(=O)[C@H](C)NC(=O)CNC(...  CNP0437004.1
# 1  COC1=CC=C(CCO[C@@H]2O[C@H](CO[C@@H]3O[C@@H](C)...  CNP0243002.1
# 2  C/C1=C\[C@@H](C(C)(C)C)OC(=O)[C@H](CC(C)C)N(C)...  CNP0458114.1
# 3  COC1=CC=C(C2=CC(=O)OC3=CC(O[C@@H]4O[C@H](CO)[C...  CNP0252086.2
# 4  CC[C@H](C)[C@H]1C(=O)N2CCC[C@H]2C(=O)N1C(=O)[C...  CNP0107934.1
#
#                                FILTER        MW    LogP  HBD  HBA    TPSA  Rot
# 0          Filter41_12_dicarbonyl > 0  1006.062 -4.4544   10   16  360.42   13
# 1                                  OK   476.475 -2.3884    7   12  187.76    8
# 2                 Filter87_crowns > 0   675.912  3.2885    2    7  145.43    3
# 3  Filter14_thio_oxopyrylium_salt > 0   430.409  0.6473    4    9  138.82    5
# 4                                  OK   559.711  2.9529    2    5  105.82    6

# %% [markdown]
# - FILTER의 경우의 수를 파악하기 위해서 collection의 Counter를 사용한다
#  - 통과한 수(OK)는 69148이다
#  - 1,2 디카르보닐 구조를 포하여 통과하지 못한 경우는 19330이다 (이는 아미노산 셀린 또는 시스테인과 공유결합을 형성하는 것으로 알려져 있다)
#  - filter_collection.CSV 파일을 보면 1,2디카르보닐 구조를 의미하는 SMARTS 문자열'*C(=O)C(=O)*'를 확인할 수 있다.

# %%
from collections import Counter
count_list = list(Counter(df.FILTER).items())
count_df = pd.DataFrame(count_list,columns=["Rule","Count"])
count_df.sort_values("Count",inplace=True,ascending=False)
count_df.head()
# Out:
#                                   Rule   Count
# 1                                   OK  355114
# 4       Filter44_michael_acceptor2 > 0  106620
# 3   Filter14_thio_oxopyrylium_salt > 0   65743
# 6               Filter33_c10_alkyl > 0   44924
# 10      Filter40_epoxide_aziridine > 0   24468

# %%
dicarbonyl = Chem.MolFromSmarts('*C(=O)C(=O)*')
dicarbonyl

# %%
smiles_list = df[df.FILTER == "Filter41_12_dicarbonyl > 0"].SMILES[:10]
mol_list = [Chem.MolFromSmiles(x) for x in smiles_list]
match_list = [mol.GetSubstructMatch(dicarbonyl) for mol in mol_list]
Draw.MolsToGridImage(mol_list,highlightAtomLists=match_list,molsPerRow=5)

# %% [markdown]
# # 모델 사용하기
# - GCN 모델을 불러오고, 피처화기를 만든후, 분자 데이터를 피처화 한다
# - 예측값을 확인하고 가장 높은 점수를 얻은 화학구조를 확인한다
# - 분자 데이터를 CSV로 저장한다

# %%
# 저장된 모델 불러오기
# model = dc.models.GraphConvModel(1, batch_size=128,
#           mode='classification',model_dir="model_dir")
# model.restore()

# %%
df = pd.read_csv("./COCONUT_DB_absoluteSMILES.smi",sep=" ",header=None)
df.columns=["SMILES","Name"]
rows,cols = df.shape
df["Val"] = [0] * rows # 피처화를 위한 빈 자리
df.head()
# Out:
#                                               SMILES          Name  Val
# 0  CC[C@@H]1NC(=O)[C@@H](NC(=O)[C@H](C)NC(=O)CNC(...  CNP0437004.1    0
# 1  COC1=CC=C(CCO[C@@H]2O[C@H](CO[C@@H]3O[C@@H](C)...  CNP0243002.1    0
# 2  C/C1=C\[C@@H](C(C)(C)C)OC(=O)[C@H](CC(C)C)N(C)...  CNP0458114.1    0
# 3  COC1=CC=C(C2=CC(=O)OC3=CC(O[C@@H]4O[C@H](CO)[C...  CNP0252086.2    0
# 4  CC[C@H](C)[C@H]1C(=O)N2CCC[C@H]2C(=O)N1C(=O)[C...  CNP0107934.1    0

# %%
infile_name = "coconut_filtered.csv"
df.to_csv(infile_name,index=False)

# %% [markdown]
# - CSV 파일을 읽어온다
# - dataset을 만든후 모델을 사용하기 위해서 피처화를 수행한다
#  - ConvMolFeaturizer 사용
# - 시간이 오래걸린다 (7분)

# %%
loader = dc.data.CSVLoader(tasks=['Val'], feature_field="SMILES", featurizer=featurizer)
dataset = loader.create_dataset(infile_name, shard_size=8192)

pred = model.predict(dataset)
# Out:
# [15:18:20] WARNING: not removing hydrogen atom without neighbors
# [15:36:34] Unusual charge on atom 37 number of radical electrons set to zero
# [15:52:52] WARNING: not removing hydrogen atom without neighbors
# [15:54:50] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# - 활성화와 비활성화를 구분하기 위해서 점수를 시각화 한다
# - SMILES와 예측값이 있는 데이터프레임을 합친다
# - 예측값이 높은 분자를 살펴본다
#  - 아래 그림에서 0.3 이상을 선택하겠다

# %%
pred_df = pd.DataFrame([x.flatten() for x in pred],columns=["Neg","Pos"])
sns.displot(x=pred_df.Pos,kind="kde",rug=True)

# %%
combo_df = df.join(pred_df,how="outer")
combo_df.sort_values("Pos",inplace=True,ascending=False)
PandasTools.AddMoleculeColumnToFrame(combo_df,"SMILES","Mol")
combo_df.head()

# %%
Draw.MolsToGridImage(combo_df.Mol[:10],molsPerRow=5,legends=["%.2f" % x for x in combo_df.Pos[:10]])

# %% [markdown]
# - 예측값이 높는 분자들의 모양이 비슷한 것을 알 수 있다
# - 중복되는 것을 피하기 위해서 군집화를 수행한다
#  - 화학적 유사성을 사용하는 Butina 군집화를 사용하겠다
#  - 군집화를 하려면 기준값을 주어야 한다 (아래에서 Tanimoto 유사도 > 0.35)

# %%
def butina_cluster(mol_list,cutoff=0.35):
    fp_list = [rdmd.GetMorganFingerprintAsBitVect(m, 3, nBits=2048) for m in mol_list]
    dists = []
    nfps = len(fp_list)
    for i in range(1,nfps):
        sims = DataStructs.BulkTanimotoSimilarity(fp_list[i],fp_list[:i])
        dists.extend([1-x for x in sims])
    mol_clusters = Butina.ClusterData(dists,nfps,cutoff,isDistData=True)
    cluster_id_list = [0]*nfps
    for idx,cluster in enumerate(mol_clusters,1):
        for member in cluster:
            cluster_id_list[member] = idx
    return cluster_id_list

# %%
best_100_df = combo_df.head(100).copy()
best_100_df["Cluster"] = butina_cluster(best_100_df.Mol)
best_100_df[:5]

# %%
best_cluster_rep_df = best_100_df.drop_duplicates("Cluster")
print(best_cluster_rep_df.shape)
best_cluster_rep_df

# %% [markdown]
# - 결과를 파일로 저장하기

# %%
best_cluster_rep_df.to_csv("best_cluster_represenatives.csv")
